# %%
1 + 2
# Out:
# 3

# %% [markdown]
# ```{code-cell} python
# import ipywidgets as widgets
# from IPython.display import display
#
# numerical_input = widgets.FloatText(
#     value=0.0,
#     description='Enter a number:',
#     disabled=False
# )
# display(numerical_input)
# ```

# %%
numerical_input.value + 2
