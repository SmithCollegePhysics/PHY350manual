# %% [markdown]
# ```{code-cell} python
# import ipywidgets as widgets
# numerical_input = widgets.FloatText(
#     value=0.0,
#     description='Enter a number:',
#     disabled=False
# )
# user_number = numerical_input.value
# ```

# %%
user_number + 2
